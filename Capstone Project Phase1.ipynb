# %% [markdown]
# PHASE 1

# %% [markdown]
# REQUIREMENT 1

# %% [markdown]
# The population of each state.

# %%
import pandas as pd

# %%
df=pd.read_csv('population.csv', sep='\t')

# %%
df
# Out:
#     S.No.                    State/ Union Territory Population (2011 Census)
# 0       1                            Uttar Pradesh               199,581,477
# 1       2                               Maharashtra              112,372,972
# 2       3                                     Bihar              103,804,637
# 3       4                              West Bengal                91,347,736
# 4       5                            Andhra Pradesh               84,665,533
# 5       6                            Madhya Pradesh               72,597,565
# 6       7                                Tamil Nadu               72,138,958
# 7       8                                 Rajasthan               68,621,012
# 8       9                                 Karnataka               61,130,704
# 9      10                                    Gujrat               60,383,628
# 10     11                                   Odisha                41,947,358
# ...

# %%
df.head()#top 5 rows
# Out:
#    S.No. State/ Union Territory Population (2011 Census)
# 0      1         Uttar Pradesh               199,581,477
# 1      2            Maharashtra              112,372,972
# 2      3                  Bihar              103,804,637
# 3      4           West Bengal                91,347,736
# 4      5         Andhra Pradesh               84,665,533

# %%
df.tail()#bottom 5 rows
# Out:
#     S.No.                    State/ Union Territory Population (2011 Census)
# 31     32                                Chandigarh                1,054,686
# 32     33  Dadra and Nagar Haveli and Daman and Diu                  585,764
# 33     34              Andaman and Nicobar Islands                   379,944
# 34     35                                    Ladakh                  274,289
# 35     36                               Lakshadweep                   64,429

# %%
df.sample()#randomly selected row
# Out:
#     S.No. State/ Union Territory Population (2011 Census)
# 24     25                Manipur                2,721,756

# %%
df.keys()#columns
# Out:
# Index(['S.No.', 'State/ Union Territory', 'Population (2011 Census)'], dtype='object')

# %%
df.dtypes#data types
# Out:
# S.No.                        int64
# State/ Union Territory      object
# Population (2011 Census)    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   S.No.                     36 non-null     int64
#  1   State/ Union Territory    36 non-null     object
#  2   Population (2011 Census)  36 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 996.0+ bytes

# %%
df.shape
# Out:
# (36, 3)

# %%
df.describe()#statiscal information
# Out:
#            S.No.
# count  36.000000
# mean   18.500000
# std    10.535654
# min     1.000000
# 25%     9.750000
# 50%    18.500000
# 75%    27.250000
# max    36.000000

# %% [markdown]
# REQUIREMENT 2

# %% [markdown]
# Literacy Rate in each state

# %%
df2=pd.read_csv('literacy rate.csv',sep='\t')

# %%
df2
# Out:
#              States & UTs   Male Literacy Rate %  Female Literacy Rate %  \
# 0              A&N islands                 90.11                   81.84
# 1           Andhra Pradesh                 73.40                   59.50
# 2        Arunachal Pradesh                 73.69                   59.57
# 3                    Assam                 90.10                   81.20
# 4                    Bihar                 79.70                   60.50
# 5               Chandigarh                 90.54                   81.38
# 6             Chhattisgarh                 85.40                   68.70
# 7   Dadra and Nagar Haveli                 86.46                   65.93
# 8              Daman & Diu                 91.48                   79.59
# 9                    Delhi                 93.70                   82.40
# 10                     Goa                 92.81                   81.84
# 11                 Gujarat                 89.50                   74.80
# ...

# %%
df2.head()#top 5 rows
# Out:
#        States & UTs   Male Literacy Rate %  Female Literacy Rate %  \
# 0        A&N islands                 90.11                   81.84
# 1     Andhra Pradesh                 73.40                   59.50
# 2  Arunachal Pradesh                 73.69                   59.57
# 3              Assam                 90.10                   81.20
# 4              Bihar                 79.70                   60.50
#
#    Average Literacy Rate %
# 0                    86.27
# 1                    66.40
# 2                    66.95
# 3                    85.90
# 4                    70.90

# %%
df2.tail()#bottom 5 rows
# Out:
#     States & UTs   Male Literacy Rate %  Female Literacy Rate %  \
# 31      Telangana                 80.50                   65.10
# 32        Tripura                 92.18                   83.15
# 33  Uttar Pradesh                 81.80                   63.40
# 34    Uttarakhand                 94.30                   80.70
# 35    West Bengal                 84.80                   76.10
#
#     Average Literacy Rate %
# 31                    72.80
# 32                    87.75
# 33                    73.00
# 34                    87.60
# 35                    80.50

# %%
df2.sample()#randomly selected row
# Out:
#    States & UTs   Male Literacy Rate %  Female Literacy Rate %  \
# 34   Uttarakhand                  94.3                    80.7
#
#     Average Literacy Rate %
# 34                     87.6

# %%
df2.shape #no.of rows/columns
# Out:
# (36, 4)

# %%
df2.info()#information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   States & UTs             36 non-null     object
#  1   Male Literacy Rate %     36 non-null     float64
#  2   Female Literacy Rate %   36 non-null     float64
#  3   Average Literacy Rate %  36 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 1.3+ KB

# %%
df2.describe()#statiscal info.
# Out:
#        Male Literacy Rate %  Female Literacy Rate %  Average Literacy Rate %
# count             36.000000               36.000000                36.000000
# mean              86.948889               74.528889                81.032500
# std                5.968365                9.086592                 7.247018
# min               73.400000               57.600000                66.400000
# 25%               83.217500               67.482500                76.770000
# 50%               87.595000               76.265000                81.350000
# 75%               91.640000               81.205000                86.562500
# max               97.400000               95.200000                96.200000

# %%
df2.dtypes#data types
# Out:
# States & UTs                object
# Male Literacy Rate %       float64
# Female Literacy Rate %     float64
# Average Literacy Rate %    float64
# dtype: object

# %%
df2.keys()#columns
# Out:
# Index(['States & UTs ', 'Male Literacy Rate %', 'Female Literacy Rate %',
#        'Average Literacy Rate %'],
#       dtype='object')

# %% [markdown]
# Requirement 3

# %% [markdown]
# Area Of Each State

# %%
df3=pd.read_csv('area.csv',sep='\t')

# %%
df3
# Out:
#    Rank                              State/UT  Area(sq km)  Area(sq mile)
# 0     1                             Rajasthan       342239         132139
# 1     2                        Madhya Pradesh       308252         119017
# 2     3                           Maharashtra       307713         118809
# 3     4                         Uttar Pradesh       240928          93023
# 4     5                               Gujarat       196244          75770
# 5     6                             Karnataka       191791          74051
# 6   UT1                                Ladakh       166698          64362
# 7     7                        Andhra Pradesh       162970          62923
# 8     8                                Odisha       155707          60119
# 9     9                          Chhattisgarh       135192          52198
# 10   10                            Tamil Nadu       130060          50216
# 11   11                             Telangana       112077          43273
# ...

# %%
df3.head()#top 5 rows
# Out:
#   Rank        State/UT  Area(sq km)  Area(sq mile)
# 0    1       Rajasthan       342239         132139
# 1    2  Madhya Pradesh       308252         119017
# 2    3     Maharashtra       307713         118809
# 3    4   Uttar Pradesh       240928          93023
# 4    5         Gujarat       196244          75770

# %%
df3.tail()#bottom 5 rows
# Out:
#    Rank                              State/UT  Area(sq km)  Area(sq mile)
# 31  NCT                                 Delhi         1483            573
# 32  UT4  Dadra & Nagar Haveli and Daman & Diu          603            233
# 33  UT5                            Puducherry          490            189
# 34  UT6                            Chandigarh          114             44
# 35  UT7                           Lakshadweep           32             12

# %%
df3.sample()#randomly selected row
# Out:
#   Rank        State/UT  Area(sq km)  Area(sq mile)
# 1    2  Madhya Pradesh       308252         119017

# %%
df3.keys()#columns
# Out:
# Index(['Rank', 'State/UT', 'Area(sq km)', 'Area(sq mile)'], dtype='object')

# %%
df3.shape #row/col
# Out:
# (36, 4)

# %%
df3.dtypes #data types
# Out:
# Rank             object
# State/UT         object
# Area(sq km)       int64
# Area(sq mile)     int64
# dtype: object

# %%
df3.info()#informatio
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           36 non-null     object
#  1   State/UT       36 non-null     object
#  2   Area(sq km)    36 non-null     int64
#  3   Area(sq mile)  36 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 1.3+ KB

# %%
df3.describe()#statiscal info
# Out:
#          Area(sq km)  Area(sq mile)
# count      36.000000      36.000000
# mean    91318.722222   35258.305556
# std     95556.725846   36894.692945
# min        32.000000      12.000000
# 25%     15055.750000    5813.000000
# 50%     55605.500000   21469.000000
# 75%    140320.750000   54178.250000
# max    342239.000000  132139.000000

# %% [markdown]
# THIS DATA IS COLLECTED FROM GOOGLE
